# %%
# !pip install pip==24.0.0
# !pip install soundstorm-pytorch==0.0.21
# !pip uninstall -y fairseq
# !pip install git+https://github.com/Tps-F/fairseq.git@main
# !pip install audiolm-pytorch
# !pip install soundfile
# Out:
# Collecting pip==24.0.0
#   Downloading pip-24.0-py3-none-any.whl.metadata (3.6 kB)
# Downloading pip-24.0-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 36.5 MB/s eta 0:00:00
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
# Successfully installed pip-24.0
# Collecting soundstorm-pytorch==0.0.21
#   Downloading soundstorm_pytorch-0.0.21-py3-none-any.whl.metadata (953 bytes)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.12/dist-packages (from soundstorm-pytorch==0.0.21) (1.12.0)
# Collecting audiolm-pytorch>=1.2.8 (from soundstorm-pytorch==0.0.21)
#   Downloading audiolm_pytorch-2.4.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: beartype in /usr/local/lib/python3.12/dist-packages (from soundstorm-pytorch==0.0.21) (0.22.8)
# Collecting classifier-free-guidance-pytorch>=0.1.5 (from soundstorm-pytorch==0.0.21)
#   Downloading classifier_free_guidance_pytorch-0.7.1-py3-none-any.whl.metadata (883 bytes)
# Requirement already satisfied: einops>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from soundstorm-pytorch==0.0.21) (0.8.1)
# Collecting spear-tts-pytorch>=0.0.6 (from soundstorm-pytorch==0.0.21)
#   Downloading spear_tts_pytorch-0.4.8-py3-none-any.whl.metadata (850 bytes)
# Requirement already satisfied: torch>=1.6 in /usr/local/lib/python3.12/dist-packages (from soundstorm-pytorch==0.0.21) (2.9.0+cu126)
# Collecting ema-pytorch>=0.2.2 (from audiolm-pytorch>=1.2.8->soundstorm-pytorch==0.0.21)
#   Downloading ema_pytorch-0.7.7-py3-none-any.whl.metadata (689 bytes)
# Collecting encodec (from audiolm-pytorch>=1.2.8->soundstorm-pytorch==0.0.21)
#   Downloading encodec-0.1.1.tar.gz (3.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 16.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting fairseq (from audiolm-pytorch>=1.2.8->soundstorm-pytorch==0.0.21)
#   Downloading fairseq-0.12.2.tar.gz (9.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.6/9.6 MB 48.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: wandb in /usr/local/lib/python3.12/dist-packages (from audiolm-pytorch>=1.2.8->soundstorm-pytorch==0.0.21) (0.23.1)
# Collecting gateloop-transformer>=0.2.3 (from audiolm-pytorch>=1.2.8->soundstorm-pytorch==0.0.21)
#   Downloading gateloop_transformer-0.2.5-py3-none-any.whl.metadata (710 bytes)
# Collecting hyper-connections>=0.1.8 (from audiolm-pytorch>=1.2.8->soundstorm-pytorch==0.0.21)
#   Downloading hyper_connections-0.2.1-py3-none-any.whl.metadata (6.0 kB)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from audiolm-pytorch>=1.2.8->soundstorm-pytorch==0.0.21) (1.5.2)
# Collecting local-attention>=1.9.0 (from audiolm-pytorch>=1.2.8->soundstorm-pytorch==0.0.21)
#   Downloading local_attention-1.11.2-py3-none-any.whl.metadata (929 bytes)
# Collecting pytorch-warmup (from audiolm-pytorch>=1.2.8->soundstorm-pytorch==0.0.21)
#   Downloading pytorch_warmup-0.2.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from audiolm-pytorch>=1.2.8->soundstorm-pytorch==0.0.21) (1.6.1)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.12/dist-packages (from audiolm-pytorch>=1.2.8->soundstorm-pytorch==0.0.21) (0.2.1)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.12/dist-packages (from audiolm-pytorch>=1.2.8->soundstorm-pytorch==0.0.21) (2.9.0+cu126)
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (from audiolm-pytorch>=1.2.8->soundstorm-pytorch==0.0.21) (4.57.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from audiolm-pytorch>=1.2.8->soundstorm-pytorch==0.0.21) (4.67.1)
# Collecting vector-quantize-pytorch>=1.19.3 (from audiolm-pytorch>=1.2.8->soundstorm-pytorch==0.0.21)
#   Downloading vector_quantize_pytorch-1.27.12-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from accelerate->soundstorm-pytorch==0.0.21) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from accelerate->soundstorm-pytorch==0.0.21) (25.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate->soundstorm-pytorch==0.0.21) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from accelerate->soundstorm-pytorch==0.0.21) (6.0.3)
# Requirement already satisfied: huggingface_hub>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from accelerate->soundstorm-pytorch==0.0.21) (0.36.0)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from accelerate->soundstorm-pytorch==0.0.21) (0.7.0)
# Collecting environs (from classifier-free-guidance-pytorch>=0.1.5->soundstorm-pytorch==0.0.21)
#   Downloading environs-14.5.0-py3-none-any.whl.metadata (16 kB)
# Collecting ftfy (from classifier-free-guidance-pytorch>=0.1.5->soundstorm-pytorch==0.0.21)
#   Downloading ftfy-6.3.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting open-clip-torch>=2.8.0 (from classifier-free-guidance-pytorch>=0.1.5->soundstorm-pytorch==0.0.21)
#   Downloading open_clip_torch-3.2.0-py3-none-any.whl.metadata (32 kB)
# Collecting rotary-embedding-torch>=0.3.0 (from spear-tts-pytorch>=0.0.6->soundstorm-pytorch==0.0.21)
#   Downloading rotary_embedding_torch-0.8.9-py3-none-any.whl.metadata (883 bytes)
# Collecting x-clip>=0.12.2 (from spear-tts-pytorch>=0.0.6->soundstorm-pytorch==0.0.21)
#   Downloading x_clip-0.14.4-py3-none-any.whl.metadata (724 bytes)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.6->soundstorm-pytorch==0.0.21) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6->soundstorm-pytorch==0.0.21) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.6->soundstorm-pytorch==0.0.21) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6->soundstorm-pytorch==0.0.21) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6->soundstorm-pytorch==0.0.21) (3.6)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6->soundstorm-pytorch==0.0.21) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6->soundstorm-pytorch==0.0.21) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6->soundstorm-pytorch==0.0.21) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6->soundstorm-pytorch==0.0.21) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6->soundstorm-pytorch==0.0.21) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6->soundstorm-pytorch==0.0.21) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6->soundstorm-pytorch==0.0.21) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6->soundstorm-pytorch==0.0.21) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6->soundstorm-pytorch==0.0.21) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6->soundstorm-pytorch==0.0.21) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6->soundstorm-pytorch==0.0.21) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6->soundstorm-pytorch==0.0.21) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6->soundstorm-pytorch==0.0.21) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6->soundstorm-pytorch==0.0.21) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6->soundstorm-pytorch==0.0.21) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6->soundstorm-pytorch==0.0.21) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6->soundstorm-pytorch==0.0.21) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6->soundstorm-pytorch==0.0.21) (3.5.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.21.0->accelerate->soundstorm-pytorch==0.0.21) (2.32.4)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.21.0->accelerate->soundstorm-pytorch==0.0.21) (1.2.0)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from open-clip-torch>=2.8.0->classifier-free-guidance-pytorch>=0.1.5->soundstorm-pytorch==0.0.21) (0.24.0+cu126)
# Requirement already satisfied: regex in /usr/local/lib/python3.12/dist-packages (from open-clip-torch>=2.8.0->classifier-free-guidance-pytorch>=0.1.5->soundstorm-pytorch==0.0.21) (2025.11.3)
# Requirement already satisfied: timm>=1.0.17 in /usr/local/lib/python3.12/dist-packages (from open-clip-torch>=2.8.0->classifier-free-guidance-pytorch>=0.1.5->soundstorm-pytorch==0.0.21) (1.0.22)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.6->soundstorm-pytorch==0.0.21) (1.3.0)
# Collecting einx>=0.3.0 (from vector-quantize-pytorch>=1.19.3->audiolm-pytorch>=1.2.8->soundstorm-pytorch==0.0.21)
#   Downloading einx-0.3.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.12/dist-packages (from environs->classifier-free-guidance-pytorch>=0.1.5->soundstorm-pytorch==0.0.21) (1.2.1)
# Collecting marshmallow>=3.18.0 (from environs->classifier-free-guidance-pytorch>=0.1.5->soundstorm-pytorch==0.0.21)
#   Downloading marshmallow-4.1.1-py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: cffi in /usr/local/lib/python3.12/dist-packages (from fairseq->audiolm-pytorch>=1.2.8->soundstorm-pytorch==0.0.21) (2.0.0)
# Requirement already satisfied: cython in /usr/local/lib/python3.12/dist-packages (from fairseq->audiolm-pytorch>=1.2.8->soundstorm-pytorch==0.0.21) (3.0.12)
# Collecting hydra-core<1.1,>=1.0.7 (from fairseq->audiolm-pytorch>=1.2.8->soundstorm-pytorch==0.0.21)
#   Downloading hydra_core-1.0.7-py3-none-any.whl.metadata (3.7 kB)
# Collecting omegaconf<2.1 (from fairseq->audiolm-pytorch>=1.2.8->soundstorm-pytorch==0.0.21)
#   Downloading omegaconf-2.0.6-py3-none-any.whl.metadata (3.0 kB)
# Collecting sacrebleu>=1.4.12 (from fairseq->audiolm-pytorch>=1.2.8->soundstorm-pytorch==0.0.21)
#   Downloading sacrebleu-2.5.1-py3-none-any.whl.metadata (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.8/51.8 kB 4.8 MB/s eta 0:00:00
# Collecting bitarray (from fairseq->audiolm-pytorch>=1.2.8->soundstorm-pytorch==0.0.21)
#   Downloading bitarray-3.8.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (34 kB)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from ftfy->classifier-free-guidance-pytorch>=0.1.5->soundstorm-pytorch==0.0.21) (0.2.14)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.6->soundstorm-pytorch==0.0.21) (3.0.3)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->audiolm-pytorch>=1.2.8->soundstorm-pytorch==0.0.21) (1.16.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->audiolm-pytorch>=1.2.8->soundstorm-pytorch==0.0.21) (3.6.0)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers->audiolm-pytorch>=1.2.8->soundstorm-pytorch==0.0.21) (0.22.1)
# Requirement already satisfied: click>=8.0.1 in /usr/local/lib/python3.12/dist-packages (from wandb->audiolm-pytorch>=1.2.8->soundstorm-pytorch==0.0.21) (8.3.1)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb->audiolm-pytorch>=1.2.8->soundstorm-pytorch==0.0.21) (3.1.45)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.12/dist-packages (from wandb->audiolm-pytorch>=1.2.8->soundstorm-pytorch==0.0.21) (4.5.1)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<7,>=3.19.0 in /usr/local/lib/python3.12/dist-packages (from wandb->audiolm-pytorch>=1.2.8->soundstorm-pytorch==0.0.21) (5.29.5)
# Requirement already satisfied: pydantic<3 in /usr/local/lib/python3.12/dist-packages (from wandb->audiolm-pytorch>=1.2.8->soundstorm-pytorch==0.0.21) (2.12.3)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb->audiolm-pytorch>=1.2.8->soundstorm-pytorch==0.0.21) (2.47.0)
# Requirement already satisfied: frozendict in /usr/local/lib/python3.12/dist-packages (from einx>=0.3.0->vector-quantize-pytorch>=1.19.3->audiolm-pytorch>=1.2.8->soundstorm-pytorch==0.0.21) (2.4.7)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb->audiolm-pytorch>=1.2.8->soundstorm-pytorch==0.0.21) (4.0.12)
# Collecting antlr4-python3-runtime==4.8 (from hydra-core<1.1,>=1.0.7->fairseq->audiolm-pytorch>=1.2.8->soundstorm-pytorch==0.0.21)
#   Downloading antlr4-python3-runtime-4.8.tar.gz (112 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.4/112.4 kB 12.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->wandb->audiolm-pytorch>=1.2.8->soundstorm-pytorch==0.0.21) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->wandb->audiolm-pytorch>=1.2.8->soundstorm-pytorch==0.0.21) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->wandb->audiolm-pytorch>=1.2.8->soundstorm-pytorch==0.0.21) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub>=0.21.0->accelerate->soundstorm-pytorch==0.0.21) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub>=0.21.0->accelerate->soundstorm-pytorch==0.0.21) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub>=0.21.0->accelerate->soundstorm-pytorch==0.0.21) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub>=0.21.0->accelerate->soundstorm-pytorch==0.0.21) (2025.11.12)
# Collecting portalocker (from sacrebleu>=1.4.12->fairseq->audiolm-pytorch>=1.2.8->soundstorm-pytorch==0.0.21)
#   Downloading portalocker-3.2.0-py3-none-any.whl.metadata (8.7 kB)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.12/dist-packages (from sacrebleu>=1.4.12->fairseq->audiolm-pytorch>=1.2.8->soundstorm-pytorch==0.0.21) (0.9.0)
# Collecting colorama (from sacrebleu>=1.4.12->fairseq->audiolm-pytorch>=1.2.8->soundstorm-pytorch==0.0.21)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.12/dist-packages (from sacrebleu>=1.4.12->fairseq->audiolm-pytorch>=1.2.8->soundstorm-pytorch==0.0.21) (6.0.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi->fairseq->audiolm-pytorch>=1.2.8->soundstorm-pytorch==0.0.21) (2.23)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision->open-clip-torch>=2.8.0->classifier-free-guidance-pytorch>=0.1.5->soundstorm-pytorch==0.0.21) (11.3.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb->audiolm-pytorch>=1.2.8->soundstorm-pytorch==0.0.21) (5.0.2)
# Downloading soundstorm_pytorch-0.0.21-py3-none-any.whl (12 kB)
# Downloading audiolm_pytorch-2.4.0-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.2/44.2 kB 4.6 MB/s eta 0:00:00
# Downloading classifier_free_guidance_pytorch-0.7.1-py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 53.9 MB/s eta 0:00:00
# Downloading spear_tts_pytorch-0.4.8-py3-none-any.whl (20 kB)
# Downloading ema_pytorch-0.7.7-py3-none-any.whl (9.8 kB)
# Downloading gateloop_transformer-0.2.5-py3-none-any.whl (10 kB)
# Downloading hyper_connections-0.2.1-py3-none-any.whl (16 kB)
# Downloading local_attention-1.11.2-py3-none-any.whl (9.5 kB)
# Downloading open_clip_torch-3.2.0-py3-none-any.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 63.1 MB/s eta 0:00:00
# Downloading rotary_embedding_torch-0.8.9-py3-none-any.whl (5.9 kB)
# Downloading vector_quantize_pytorch-1.27.12-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.6/52.6 kB 5.8 MB/s eta 0:00:00
# Downloading x_clip-0.14.4-py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 60.0 MB/s eta 0:00:00
# Downloading environs-14.5.0-py3-none-any.whl (17 kB)
# Downloading ftfy-6.3.1-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 4.8 MB/s eta 0:00:00
# Downloading pytorch_warmup-0.2.0-py3-none-any.whl (11 kB)
# Downloading einx-0.3.0-py3-none-any.whl (102 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.0/103.0 kB 13.1 MB/s eta 0:00:00
# Downloading hydra_core-1.0.7-py3-none-any.whl (123 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.8/123.8 kB 13.6 MB/s eta 0:00:00
# Downloading marshmallow-4.1.1-py3-none-any.whl (48 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.3/48.3 kB 5.1 MB/s eta 0:00:00
# Downloading omegaconf-2.0.6-py3-none-any.whl (36 kB)
# Downloading sacrebleu-2.5.1-py3-none-any.whl (104 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.1/104.1 kB 12.8 MB/s eta 0:00:00
# Downloading bitarray-3.8.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (340 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 340.3/340.3 kB 37.9 MB/s eta 0:00:00
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Downloading portalocker-3.2.0-py3-none-any.whl (22 kB)
# Building wheels for collected packages: encodec, fairseq, antlr4-python3-runtime
#   Building wheel for encodec (setup.py) ... done
#   Created wheel for encodec: filename=encodec-0.1.1-py3-none-any.whl size=45759 sha256=f7608259885e9924d1685f26cdc88e754d43a8b2aa9bf9aeecf2a45fa801585a
#   Stored in directory: /root/.cache/pip/wheels/b8/eb/9f/e13610cc46ab39d3199fbabebd1c3e142d44b679526e0f228a
#   Building wheel for fairseq (pyproject.toml) ... done
#   Created wheel for fairseq: filename=fairseq-0.12.2-cp312-cp312-linux_x86_64.whl size=11301992 sha256=269a76a11002b6ff5425e786a77809d8753ffaacc6daafacfac26ab1ddd79491
#   Stored in directory: /root/.cache/pip/wheels/33/f8/a7/58ad0492b276ba117d7fb01ec38a447a3b1ae9c535952e1c9f
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.8-py3-none-any.whl size=141211 sha256=846dda8472ac65106eb617c1d9bfab2d40278d10f8dd89c85e509f1617225536
#   Stored in directory: /root/.cache/pip/wheels/3e/92/b7/08c6a108fc5bf6370a7540d11bbe9befc99b7e045ac7558d49
# Successfully built encodec fairseq antlr4-python3-runtime
# DEPRECATION: omegaconf 2.0.6 has a non-standard dependency specifier PyYAML>=5.1.*. pip 24.1 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of omegaconf or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
# Installing collected packages: bitarray, antlr4-python3-runtime, portalocker, omegaconf, marshmallow, ftfy, colorama, sacrebleu, hydra-core, environs, einx, vector-quantize-pytorch, rotary-embedding-torch, pytorch-warmup, hyper-connections, ema-pytorch, x-clip, local-attention, gateloop-transformer, fairseq, encodec, open-clip-torch, audiolm-pytorch, spear-tts-pytorch, classifier-free-guidance-pytorch, soundstorm-pytorch
#   Attempting uninstall: antlr4-python3-runtime
#     Found existing installation: antlr4-python3-runtime 4.9.3
#     Uninstalling antlr4-python3-runtime-4.9.3:
#       Successfully uninstalled antlr4-python3-runtime-4.9.3
#   Attempting uninstall: omegaconf
#     Found existing installation: omegaconf 2.3.0
#     Uninstalling omegaconf-2.3.0:
#       Successfully uninstalled omegaconf-2.3.0
# Successfully installed antlr4-python3-runtime-4.8 audiolm-pytorch-2.4.0 bitarray-3.8.0 classifier-free-guidance-pytorch-0.7.1 colorama-0.4.6 einx-0.3.0 ema-pytorch-0.7.7 encodec-0.1.1 environs-14.5.0 fairseq-0.12.2 ftfy-6.3.1 gateloop-transformer-0.2.5 hydra-core-1.0.7 hyper-connections-0.2.1 local-attention-1.11.2 marshmallow-4.1.1 omegaconf-2.0.6 open-clip-torch-3.2.0 portalocker-3.2.0 pytorch-warmup-0.2.0 rotary-embedding-torch-0.8.9 sacrebleu-2.5.1 soundstorm-pytorch-0.0.21 spear-tts-pytorch-0.4.8 vector-quantize-pytorch-1.27.12 x-clip-0.14.4
# Found existing installation: fairseq 0.12.2
# Uninstalling fairseq-0.12.2:
#   Successfully uninstalled fairseq-0.12.2
# Collecting git+https://github.com/Tps-F/fairseq.git@main
#   Cloning https://github.com/Tps-F/fairseq.git (to revision main) to /tmp/pip-req-build-070dhexc
#   Running command git clone --filter=blob:none --quiet https://github.com/Tps-F/fairseq.git /tmp/pip-req-build-070dhexc
#   Resolved https://github.com/Tps-F/fairseq.git to commit ff08af27e302625a27d3502b0791a9367c8af0c7
#   Running command git submodule update --init --recursive -q
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: cffi in /usr/local/lib/python3.12/dist-packages (from fairseq==0.12.2) (2.0.0)
# Requirement already satisfied: cython in /usr/local/lib/python3.12/dist-packages (from fairseq==0.12.2) (3.0.12)
# Collecting hydra-core>=1.3.2 (from fairseq==0.12.2)
#   Downloading hydra_core-1.3.2-py3-none-any.whl.metadata (5.5 kB)
# Collecting omegaconf>2.1 (from fairseq==0.12.2)
#   Downloading omegaconf-2.3.0-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: numpy>=1.21.3 in /usr/local/lib/python3.12/dist-packages (from fairseq==0.12.2) (2.0.2)
# Requirement already satisfied: regex in /usr/local/lib/python3.12/dist-packages (from fairseq==0.12.2) (2025.11.3)
# Requirement already satisfied: sacrebleu>=1.4.12 in /usr/local/lib/python3.12/dist-packages (from fairseq==0.12.2) (2.5.1)
# Requirement already satisfied: torch>=1.13 in /usr/local/lib/python3.12/dist-packages (from fairseq==0.12.2) (2.9.0+cu126)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from fairseq==0.12.2) (4.67.1)
# Requirement already satisfied: bitarray in /usr/local/lib/python3.12/dist-packages (from fairseq==0.12.2) (3.8.0)
# Requirement already satisfied: torchaudio>=0.8.0 in /usr/local/lib/python3.12/dist-packages (from fairseq==0.12.2) (2.9.0+cu126)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from fairseq==0.12.2) (1.6.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from fairseq==0.12.2) (25.0)
# Collecting antlr4-python3-runtime==4.9.* (from hydra-core>=1.3.2->fairseq==0.12.2)
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 3.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: PyYAML>=5.1.0 in /usr/local/lib/python3.12/dist-packages (from omegaconf>2.1->fairseq==0.12.2) (6.0.3)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.12/dist-packages (from sacrebleu>=1.4.12->fairseq==0.12.2) (3.2.0)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.12/dist-packages (from sacrebleu>=1.4.12->fairseq==0.12.2) (0.9.0)
# Requirement already satisfied: colorama in /usr/local/lib/python3.12/dist-packages (from sacrebleu>=1.4.12->fairseq==0.12.2) (0.4.6)
# Requirement already satisfied: lxml in /usr/local/lib/python3.12/dist-packages (from sacrebleu>=1.4.12->fairseq==0.12.2) (6.0.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.13->fairseq==0.12.2) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13->fairseq==0.12.2) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.13->fairseq==0.12.2) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13->fairseq==0.12.2) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13->fairseq==0.12.2) (3.6)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13->fairseq==0.12.2) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13->fairseq==0.12.2) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13->fairseq==0.12.2) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13->fairseq==0.12.2) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13->fairseq==0.12.2) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13->fairseq==0.12.2) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13->fairseq==0.12.2) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13->fairseq==0.12.2) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13->fairseq==0.12.2) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13->fairseq==0.12.2) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13->fairseq==0.12.2) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13->fairseq==0.12.2) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13->fairseq==0.12.2) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13->fairseq==0.12.2) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13->fairseq==0.12.2) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13->fairseq==0.12.2) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13->fairseq==0.12.2) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13->fairseq==0.12.2) (3.5.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi->fairseq==0.12.2) (2.23)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->fairseq==0.12.2) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->fairseq==0.12.2) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->fairseq==0.12.2) (3.6.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.13->fairseq==0.12.2) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.13->fairseq==0.12.2) (3.0.3)
# Downloading hydra_core-1.3.2-py3-none-any.whl (154 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 6.2 MB/s eta 0:00:00
# Downloading omegaconf-2.3.0-py3-none-any.whl (79 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 5.2 MB/s eta 0:00:00
# Building wheels for collected packages: fairseq, antlr4-python3-runtime
#   Building wheel for fairseq (pyproject.toml) ... done
#   Created wheel for fairseq: filename=fairseq-0.12.2-cp312-cp312-linux_x86_64.whl size=21330882 sha256=d58857d25d68d5148746c96237d901615812083886f883206f4b4b91d9b5eea0
#   Stored in directory: /tmp/pip-ephem-wheel-cache-fswvv2i8/wheels/8c/1d/1b/07cfb826b79161b459696fd47eb54cef88687aa9bf98ad9e79
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144554 sha256=66d94dfc0b913c0d115fdca6a08e855ea86c9ea3122a8695e60d9901a2bd1c31
#   Stored in directory: /root/.cache/pip/wheels/1f/be/48/13754633f1d08d1fbfc60d5e80ae1e5d7329500477685286cd
# Successfully built fairseq antlr4-python3-runtime
# Installing collected packages: antlr4-python3-runtime, omegaconf, hydra-core, fairseq
#   Attempting uninstall: antlr4-python3-runtime
#     Found existing installation: antlr4-python3-runtime 4.8
#     Uninstalling antlr4-python3-runtime-4.8:
#       Successfully uninstalled antlr4-python3-runtime-4.8
#   Attempting uninstall: omegaconf
#     Found existing installation: omegaconf 2.0.6
#     Uninstalling omegaconf-2.0.6:
#       Successfully uninstalled omegaconf-2.0.6
#   Attempting uninstall: hydra-core
#     Found existing installation: hydra-core 1.0.7
#     Uninstalling hydra-core-1.0.7:
#       Successfully uninstalled hydra-core-1.0.7
# Successfully installed antlr4-python3-runtime-4.9.3 fairseq-0.12.2 hydra-core-1.3.2 omegaconf-2.3.0
# Requirement already satisfied: audiolm-pytorch in /usr/local/lib/python3.12/dist-packages (2.4.0)
# Requirement already satisfied: accelerate>=0.24.0 in /usr/local/lib/python3.12/dist-packages (from audiolm-pytorch) (1.12.0)
# Requirement already satisfied: beartype>=0.16.1 in /usr/local/lib/python3.12/dist-packages (from audiolm-pytorch) (0.22.8)
# Requirement already satisfied: einops>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from audiolm-pytorch) (0.8.1)
# Requirement already satisfied: ema-pytorch>=0.2.2 in /usr/local/lib/python3.12/dist-packages (from audiolm-pytorch) (0.7.7)
# Requirement already satisfied: encodec in /usr/local/lib/python3.12/dist-packages (from audiolm-pytorch) (0.1.1)
# Requirement already satisfied: fairseq in /usr/local/lib/python3.12/dist-packages (from audiolm-pytorch) (0.12.2)
# Requirement already satisfied: wandb in /usr/local/lib/python3.12/dist-packages (from audiolm-pytorch) (0.23.1)
# Requirement already satisfied: gateloop-transformer>=0.2.3 in /usr/local/lib/python3.12/dist-packages (from audiolm-pytorch) (0.2.5)
# Requirement already satisfied: hyper-connections>=0.1.8 in /usr/local/lib/python3.12/dist-packages (from audiolm-pytorch) (0.2.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from audiolm-pytorch) (1.5.2)
# Requirement already satisfied: local-attention>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from audiolm-pytorch) (1.11.2)
# Requirement already satisfied: pytorch-warmup in /usr/local/lib/python3.12/dist-packages (from audiolm-pytorch) (0.2.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from audiolm-pytorch) (1.6.1)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.12/dist-packages (from audiolm-pytorch) (0.2.1)
# Requirement already satisfied: torch>=2.1 in /usr/local/lib/python3.12/dist-packages (from audiolm-pytorch) (2.9.0+cu126)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.12/dist-packages (from audiolm-pytorch) (2.9.0+cu126)
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (from audiolm-pytorch) (4.57.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from audiolm-pytorch) (4.67.1)
# Requirement already satisfied: vector-quantize-pytorch>=1.19.3 in /usr/local/lib/python3.12/dist-packages (from audiolm-pytorch) (1.27.12)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from accelerate>=0.24.0->audiolm-pytorch) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from accelerate>=0.24.0->audiolm-pytorch) (25.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate>=0.24.0->audiolm-pytorch) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from accelerate>=0.24.0->audiolm-pytorch) (6.0.3)
# Requirement already satisfied: huggingface_hub>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from accelerate>=0.24.0->audiolm-pytorch) (0.36.0)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from accelerate>=0.24.0->audiolm-pytorch) (0.7.0)
# Requirement already satisfied: rotary-embedding-torch in /usr/local/lib/python3.12/dist-packages (from gateloop-transformer>=0.2.3->audiolm-pytorch) (0.8.9)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->audiolm-pytorch) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->audiolm-pytorch) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->audiolm-pytorch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->audiolm-pytorch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->audiolm-pytorch) (3.6)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->audiolm-pytorch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->audiolm-pytorch) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->audiolm-pytorch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->audiolm-pytorch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->audiolm-pytorch) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->audiolm-pytorch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->audiolm-pytorch) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->audiolm-pytorch) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->audiolm-pytorch) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->audiolm-pytorch) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->audiolm-pytorch) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->audiolm-pytorch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->audiolm-pytorch) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->audiolm-pytorch) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->audiolm-pytorch) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->audiolm-pytorch) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->audiolm-pytorch) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->audiolm-pytorch) (3.5.0)
# Requirement already satisfied: einx>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from vector-quantize-pytorch>=1.19.3->audiolm-pytorch) (0.3.0)
# Requirement already satisfied: cffi in /usr/local/lib/python3.12/dist-packages (from fairseq->audiolm-pytorch) (2.0.0)
# Requirement already satisfied: cython in /usr/local/lib/python3.12/dist-packages (from fairseq->audiolm-pytorch) (3.0.12)
# Requirement already satisfied: hydra-core>=1.3.2 in /usr/local/lib/python3.12/dist-packages (from fairseq->audiolm-pytorch) (1.3.2)
# Requirement already satisfied: omegaconf>2.1 in /usr/local/lib/python3.12/dist-packages (from fairseq->audiolm-pytorch) (2.3.0)
# Requirement already satisfied: regex in /usr/local/lib/python3.12/dist-packages (from fairseq->audiolm-pytorch) (2025.11.3)
# Requirement already satisfied: sacrebleu>=1.4.12 in /usr/local/lib/python3.12/dist-packages (from fairseq->audiolm-pytorch) (2.5.1)
# Requirement already satisfied: bitarray in /usr/local/lib/python3.12/dist-packages (from fairseq->audiolm-pytorch) (3.8.0)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->audiolm-pytorch) (1.16.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->audiolm-pytorch) (3.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers->audiolm-pytorch) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers->audiolm-pytorch) (0.22.1)
# Requirement already satisfied: click>=8.0.1 in /usr/local/lib/python3.12/dist-packages (from wandb->audiolm-pytorch) (8.3.1)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb->audiolm-pytorch) (3.1.45)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.12/dist-packages (from wandb->audiolm-pytorch) (4.5.1)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<7,>=3.19.0 in /usr/local/lib/python3.12/dist-packages (from wandb->audiolm-pytorch) (5.29.5)
# Requirement already satisfied: pydantic<3 in /usr/local/lib/python3.12/dist-packages (from wandb->audiolm-pytorch) (2.12.3)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb->audiolm-pytorch) (2.47.0)
# Requirement already satisfied: frozendict in /usr/local/lib/python3.12/dist-packages (from einx>=0.3.0->vector-quantize-pytorch>=1.19.3->audiolm-pytorch) (2.4.7)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb->audiolm-pytorch) (4.0.12)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.21.0->accelerate>=0.24.0->audiolm-pytorch) (1.2.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.12/dist-packages (from hydra-core>=1.3.2->fairseq->audiolm-pytorch) (4.9.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->wandb->audiolm-pytorch) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->wandb->audiolm-pytorch) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->wandb->audiolm-pytorch) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers->audiolm-pytorch) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers->audiolm-pytorch) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers->audiolm-pytorch) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers->audiolm-pytorch) (2025.11.12)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.12/dist-packages (from sacrebleu>=1.4.12->fairseq->audiolm-pytorch) (3.2.0)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.12/dist-packages (from sacrebleu>=1.4.12->fairseq->audiolm-pytorch) (0.9.0)
# Requirement already satisfied: colorama in /usr/local/lib/python3.12/dist-packages (from sacrebleu>=1.4.12->fairseq->audiolm-pytorch) (0.4.6)
# Requirement already satisfied: lxml in /usr/local/lib/python3.12/dist-packages (from sacrebleu>=1.4.12->fairseq->audiolm-pytorch) (6.0.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.1->audiolm-pytorch) (1.3.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi->fairseq->audiolm-pytorch) (2.23)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.1->audiolm-pytorch) (3.0.3)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb->audiolm-pytorch) (5.0.2)
# Requirement already satisfied: soundfile in /usr/local/lib/python3.12/dist-packages (0.13.1)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.12/dist-packages (from soundfile) (2.0.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from soundfile) (2.0.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0->soundfile) (2.23)

# %%
import torchaudio
import os
import torchaudio.transforms as T
import matplotlib.pyplot as plt
import torch
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
from torchaudio import functional as AF
from sklearn.preprocessing import OneHotEncoder
import pandas as pd
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from pathlib import Path

# %%
from google.colab import drive
drive.mount('/content/drive')

# !cp -r "/content/drive/MyDrive/soundstorm_data/librispeech/LibriSpeech/train-clean-100" \
#       "/content/drive/MyDrive/CIS7000_project/train-clean-100"
# Out:
# Mounted at /content/drive

# %%
# Root folder where your LibriSpeech audio is stored on Drive
import torch
import torchaudio
from pathlib import Path

librispeech_path = "/content/drive/MyDrive/CIS7000_project/train-clean-100"

device = "cuda" if torch.cuda.is_available() else "cpu"
print("Using device:", device)
print("Dataset path:", librispeech_path)
# Out:
# Using device: cuda
# Dataset path: /content/drive/MyDrive/CIS7000_project/train-clean-100

# %%
# !pip install soundfile
# Out:
# Requirement already satisfied: soundfile in /usr/local/lib/python3.12/dist-packages (0.13.1)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.12/dist-packages (from soundfile) (2.0.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from soundfile) (2.0.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0->soundfile) (2.23)

# %%
import soundfile as sf
import torch
import torch.nn.functional as F
from torch.utils.data import Dataset
from pathlib import Path
from torchaudio import functional as AF

class AudioDataset_LibriSpeech(Dataset):
    def __init__(self, path, files, target_seconds=10.0):
        super().__init__()
        self.path = Path(path)
        self.files = files

        # Load first file to determine sample rate
        audio, sr = sf.read(self.files[0])
        if audio.ndim > 1:
            audio = audio.mean(axis=1)
        self.frequency = sr

        self.target_seconds = target_seconds
        self.target_len = int(sr * target_seconds)

        print(f"Loaded {len(self.files)} files, sample rate = {self.frequency} Hz")

    def __len__(self):
        return len(self.files)

    def __getitem__(self, idx):
        audio, sr = sf.read(self.files[idx])

        # Mono conversion
        if audio.ndim > 1:
            audio = audio.mean(axis=1)

        audio = torch.tensor(audio, dtype=torch.float32)

        # Resample if needed
        if sr != self.frequency:
            audio = AF.resample(audio, orig_freq=sr, new_freq=self.frequency)

        # Pad or clip
        if len(audio) < self.target_len:
            audio = F.pad(audio, (0, self.target_len - len(audio)))
        else:
            audio = audio[:self.target_len]

        return audio, audio

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
from sklearn.model_selection import train_test_split
import glob
from pathlib import Path

all_files = sorted(
    glob.glob(str(Path(librispeech_path) / "**/*.flac"), recursive=True)
)

print("Total LibriSpeech files found:", len(all_files))

train_files, val_files = train_test_split(all_files, test_size=0.10, random_state=42)

print("Train:", len(train_files))
print("Val:", len(val_files))
# Out:
# Total LibriSpeech files found: 14581
# Train: 13122
# Val: 1459

# %%
import beartype
beartype.beartype = lambda func: func

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset
import torch.optim as optim
import torchaudio
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
from tqdm.auto import tqdm

# %%
batch_size = 8  # same as original notebook

train_set = AudioDataset_LibriSpeech(librispeech_path, train_files)
val_set   = AudioDataset_LibriSpeech(librispeech_path, val_files)

train_loader = DataLoader(train_set, batch_size=batch_size, shuffle=True)
val_loader   = DataLoader(val_set, batch_size=batch_size, shuffle=False)

print("Train batches:", len(train_loader))
print("Val batches:", len(val_loader))
# Out:
# Loaded 13122 files, sample rate = 16000 Hz
# Loaded 1459 files, sample rate = 16000 Hz
# Train batches: 1641
# Val batches: 183

# %%
from soundstorm_pytorch import SoundStorm, ConformerWrapper, SoundStream
from audiolm_pytorch import SoundStreamTrainer, EncodecWrapper

# %%
class EncodecForSoundStorm:
    def __init__(self):
        self.encodec = EncodecWrapper()
        self.codebook_size = 1024
        self.num_quantizers = 8
        self.rq_num_quantizers = 8
        self.rq_groups = 1

    def __call__(self, *args, **kwargs):
        return self.encodec(*args, **kwargs)

    def encode(self, *args, **kwargs):
        return self.encodec.encode(*args, **kwargs)

    def decode(self, *args, **kwargs):
        return self.encodec.decode(*args, **kwargs)

    def __getattr__(self, name):
        return getattr(self.encodec, name)

    def to(self, *args, **kwargs):
        self.encodec = self.encodec.to(*args, **kwargs)
        return self

    def train(self, mode=True):
        self.encodec.train(mode)
        return self

    def eval(self):
        self.encodec.eval()
        return self

# %%
import beartype
beartype.beartype = lambda func: func

import os
os.environ['PYTORCH_CUDA_ALLOC_CONF'] = 'expandable_segments:True'

conformer = ConformerWrapper(
    codebook_size = 1024,
    num_quantizers = 8,
    conformer = dict(
        dim = 512,
        depth = 2
    ),
)

soundstream = SoundStream(
    codebook_size = 1024,
    rq_num_quantizers = 8,
    attn_window_size = 128,
    attn_depth = 2
)

# enc = EncodecForSoundStorm()
# enc.eval()

# model = SoundStorm(conformer, soundstream = enc).to(device)
# Out:
# Non-A100 GPU detected, using math or mem efficient attention if input tensor is on cuda

# %%
enc = EncodecForSoundStorm()
enc.eval()
enc = enc.to(device)

model = SoundStorm(conformer, soundstream = enc).to(device)
# Out:
# Downloading: "https://dl.fbaipublicfiles.com/encodec/v0/encodec_24khz-d7cc33bc.th" to /root/.cache/torch/hub/checkpoints/encodec_24khz-d7cc33bc.th
# 100%|██████████| 88.9M/88.9M [00:00<00:00, 186MB/s]

# %%
optimizer = optim.Adam(model.parameters(), lr = 0.001, weight_decay=1e-5)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, patience = 4)

# %%
def train_one_epoch(model, train_dataloader, optimizer, device, batches):
    running_loss = 0

    for i, data in enumerate(train_dataloader):
        inputs, labels = data
        inputs, labels = inputs.to(device), labels.to(device)
        optimizer.zero_grad()

        loss, _ = model(inputs)
        loss.backward()

        optimizer.step()
        running_loss += loss.item()

    last_loss = running_loss / batches
    return last_loss

# %%
def train(model, n_batches, train_dataloader, val_dataloader, scheduler, optimizer, device, epochs=20):
    epoch_number = 0
    losses = []
    vlosses = []

    for epoch in range(epochs):
        print('EPOCH {}:'.format(epoch_number + 1))

        model.train(True)

        avg_loss = train_one_epoch(model, train_dataloader, optimizer, device, n_batches)

        model.eval()
        running_vloss = 0.0

        with torch.no_grad():
            for i, vdata in enumerate(val_dataloader):
                vinputs, vlabels = vdata
                vinputs, vlabels = vinputs.to(device), vlabels.to(device)
                vloss, _ = model(vinputs)
                running_vloss += vloss.item()

        avg_vloss = running_vloss / (i + 1)
        scheduler.step(avg_vloss)

        losses.append(avg_loss)
        vlosses.append(avg_vloss)
        print('LOSS train {} val {}'.format(avg_loss, avg_vloss))

        epoch_number += 1

    df = pd.DataFrame({'loss': losses, 'val_loss': vlosses})
    df.to_csv('librispeech_losses.csv', index=False)

# %%
n_train_batches = len(train_loader)

train(
    model,
    n_train_batches,
    train_loader,
    val_loader,
    scheduler,
    optimizer,
    device,
    epochs = 20   # or set to 1 just to sanity test
)

# %%
from google.colab import runtime

runtime.unassign()
